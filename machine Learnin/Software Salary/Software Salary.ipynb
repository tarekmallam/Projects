# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Read File

# %%
df = pd.read_csv("Salary_Dataset_with_Extra_Features.csv")
#df2 = pd.read_csv("Software_Professional_Salaries.csv")

# %%
df.head()
#df2.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22770 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df.dtypes
#All data types are valid
# Out:
# Rating               float64
# Company Name          object
# Job Title             object
# Salary                 int64
# Salaries Reported      int64
# Location              object
# Employment Status     object
# Job Roles             object
# dtype: object

# %%
df.duplicated()
# No Duplicated Data
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22765    False
# 22766    False
# 22767    False
# 22768    False
# 22769    False
# Length: 22770, dtype: bool

# %%
df.isna().sum()
# No Missing Data
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df["Job Title"].value_counts()
# Out:
# Software Development Engineer          2351
# Android Developer                      2029
# Software Development Engineer (SDE)    1614
# Front End Developer                    1412
# Test Engineer                          1314
#                                        ...
# Java Andriod Developer                    1
# Java Deceloper                            1
# Java/J2EE Programmer                      1
# Java SOA Developer                        1
# Associate Web Developer                   1
# Name: Job Title, Length: 1080, dtype: int64

# %%
df["Job Title"].nunique()
# Out:
# 1080

# %%
df["Job Title"].str.contains("Developer").sum()
# Out:
# 10767

# %%
df["Job Title"].str.contains("Engineer").sum()
# Out:
# 10796

# %%
df["Job Title"].str.contains("Programmer").sum()
# Out:
# 77

# %%
job_categories = ["Developer", "Engineer", "Programmer"]

# %%
conditions = [
    (df["Job Title"].str.contains("Developer")),
    (df["Job Title"].str.contains("Engineer")),
    df["Job Title"].str.contains("Programmer")
]

# %%
df["job_category"] = np.select(conditions, job_categories, default="Other")

# %%
df[["Job Title", "job_category"]].head()
# Out:
#            Job Title job_category
# 0  Android Developer    Developer
# 1  Android Developer    Developer
# 2  Android Developer    Developer
# 3  Android Developer    Developer
# 4  Android Developer    Developer

# %%
df.drop("Job Title", axis=1, inplace=True)

# %%
df["Salaries Reported"].value_counts()
# Out:
# 1      18206
# 2       2401
# 3        789
# 4        382
# 5        228
#        ...
# 39         1
# 162        1
# 361        1
# 135        1
# 100        1
# Name: Salaries Reported, Length: 82, dtype: int64

# %%
df.drop("Salaries Reported", axis=1, inplace=True)

# %%
df["Employment Status"].value_counts()
# Out:
# Full Time     20083
# Intern         2106
# Contractor      548
# Trainee          33
# Name: Employment Status, dtype: int64

# %%
df["Job Roles"].value_counts()
# Out:
# SDE         7485
# Android     2845
# Frontend    2070
# Java        1800
# Testing     1719
# IOS         1551
# Backend     1085
# Web          989
# Python       935
# Database     760
# Mobile       220
# Name: Job Roles, dtype: int64

# %%
# 75th percentile
seventy_fifth = df["Salary"].quantile(0.75)

# 25th percentile
twenty_fifth = df["Salary"].quantile(0.25)

# Interquartile range 
salaries_iqr = seventy_fifth - twenty_fifth
print(salaries_iqr)
# Out:
# 600000.0

# %%
# Upper
upper = seventy_fifth + (salaries_iqr * 1.5)

lower = twenty_fifth - (salaries_iqr * 1.5)

print(upper)
# Out:
# 1800000.0

# %%
df[(df["Salary"] > upper)]
# Out:
#        Rating                         Company Name   Salary   Location  \
# 96        4.1                                Dunzo  2800000  Bangalore
# 106       4.0                  Walmart Global Tech  2300000  Bangalore
# 145       4.1                        First Student  2200000  Bangalore
# 161       4.4                            Microsoft  2100000  Bangalore
# 162       3.7                          Paytm Money  1900000  Bangalore
# ...       ...                                  ...      ...        ...
# 22241     3.9                      Western Digital  2400000  Bangalore
# 22271     4.1                    HealthGraph India  4400000  Bangalore
# 22274     2.9                          Sud Express  2900000  Bangalore
# 22366     4.2                              Greytip  2100000  Bangalore
# 22675     4.1  Chethan's Charters- GD FEA Employer  2016960  Bangalore
#
#       Employment Status Job Roles job_category
# 96            Full Time   Android    Developer
# 106           Full Time   Android    Developer
# 145              Intern   Android    Developer
# 161           Full Time   Android    Developer
# 162           Full Time   Android    Developer
# ...                 ...       ...          ...
# 22241         Full Time       Web    Developer
# 22271         Full Time       Web    Developer
# 22274         Full Time       Web    Developer
# 22366         Full Time       Web    Developer
# 22675         Full Time       Web    Developer
#
# [1156 rows x 7 columns]

# %%
df = df[(df["Salary"] > lower) & (df["Salary"] < upper)]

# %%
px.box(df,
       y='Salary',
       template='ggplot2',
       title='<b>Salaries')
# Out:
# <div>                            <div id="3364e7e6-b3fd-4e41-a0f5-06d57fabfea0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3364e7e6-b3fd-4e41-a0f5-06d57fabfea0")) {                    Plotly.newPlot(                        "3364e7e6-b3fd-4e41-a0f5-06d57fabfea0",                        [{"alignmentgroup":"True","hovertemplate":"Salary=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#F8766D"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[400000,400000,1000000,300000,600000,100000,192000,400000,300000,600000,300000,240000,900000,24000,600000,228000,600000,360000,1000000,500000,408000,300000,800000,228000,100000,500000,200000,500000,228000,708000,396000,700000,500000,500000,900000,200000,228000,400000,600000,400000,500000,216000,216000,300000,540000,400000,500000,400000,100000,252000,700000,100000,200000,156000,348000,600000,300000,864000,120000,400000,168000,400000,96000,1000000,420000,240000,72000,700000,396000,264000,500000,1000000,672000,276000,800000,200000,492000,600000,300000,300000,432000,200000,1188000,500000,500000,300000,1000000,400000,500000,732000,120000,684000,500000,800000,400000,200000,852000,700000,1200000,900000,400000,228000,400000,400000,252000,300000,400000,1000000,84000,468000,800000,300000,900000,700000,900000,700000,264000,240000,600000,120000,408000,1000000,228000,400000,500000,300000,700000,500000,500000,228000,500000,600000,1000000,216000,1200000,1300000,400000,120000,192000,1000000,200000,600000,300000,144000,672000,312000,348000,480000,500000,200000,228000,400000,408000,500000,432000,900000,800000,600000,180000,500000,300000,400000,252000,500000,200000,192000,100000,900000,360000,1400000,400000,252000,400000,300000,400000,800000,408000,624000,1400000,400000,240768,500000,300000,400000,600000,300000,1000000,216000,800000,576000,720000,600000,744000,1200000,216000,1100000,400000,300000,720000,120000,144000,120000,636000,1000000,200000,600000,1200000,360000,708000,300000,900000,180000,1300000,228000,600000,800000,648000,288000,372000,1300000,400000,300000,300000,192000,1200000,600000,600000,600000,504000,288000,1400000,500000,444000,800000,300000,400000,300000,252000,400000,400000,200000,1500000,384000,672000,600000,516000,588000,300000,200000,1000000,300000,168000,264000,1100000,300000,600000,552000,372000,1600000,1000000,1000000,168000,1400000,540000,144000,800000,800000,900000,168000,200000,700000,600000,200000,500000,156000,300000,400000,300000,1000000,336000,300000,228000,800000,300000,1128000,288000,228000,600000,600000,1000000,900000,800000,276000,1100000,400000,400000,800000,800000,600000,1000000,400000,400000,300000,336000,240000,1200000,500000,1200000,468000,800000,400000,300000,300000,400000,1600000,100000,1000000,288000,216000,600000,288000,100000,132000,700000,1100000,1100000,324000,744000,1000000,108000,700000,1000000,300000,1000000,372000,396000,60000,300000,396000,1200000,1500000,500000,348000,408000,672000,400000,1000000,1200000,672000,900000,192000,400000,264000,1200000,1152000,100000,1000000,700000,200000,960000,180000,400000,300000,300000,324000,192000,400000,900000,200000,1400000,240000,276000,500000,120000,252000,1300000,400000,300000,500000,1200000,500000,264000,1300000,300000,500000,600000,1600000,1100000,500000,312000,600000,660000,500000,200000,100000,700000,1200000,576000,700000,192000,600000,300000,144000,228000,500000,192000,72000,400000,200000,600000,1700000,1400000,264000,300000,108000,600000,348000,288000,200000,800000,132000,600000,1400000,864000,168000,1200000,804000,200000,288000,180000,500000,100000,700000,516000,200000,408000,500000,800000,900000,1200000,100000,600000,420000,300000,400000,800000,576000,132000,500000,1400000,900000,396000,1000000,180000,400000,60 ...

# %%
fig=px.imshow(df.corr(),
              text_auto=True,
              height=600,
              width=600,
              template='ggplot2',
              aspect='auto',
              title='<b>Correlation of columns</b>')
fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="d9314fea-0399-430a-bf60-d494f2936825" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9314fea-0399-430a-bf60-d494f2936825")) {                    Plotly.newPlot(                        "d9314fea-0399-430a-bf60-d494f2936825",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Rating","Salary"],"y":["Rating","Salary"],"z":[[1.0,0.02954456469637613],[0.02954456469637613,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattermapbox"}],"scatterpolargl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6, ...
#
# var gd = document.getElementById('d9314fea-0399-430a-bf60-d494f2936825');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#noteboo

# %%
df.dtypes
# Out:
# Rating               float64
# Company Name          object
# Salary                 int64
# Location              object
# Employment Status     object
# Job Roles             object
# job_category          object
# dtype: object

# %%
rl = df.groupby('Location', as_index=False)['Rating'].mean().sort_values(by='Rating', ascending=False)

fig = px.bar(rl,
             x = 'Location',
             y = 'Rating',
             color = 'Location',
             template = 'ggplot2',
             title = '<b> Rating of Location')
fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="f00cc7fb-ce46-43fe-9b83-070b1fd15edb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f00cc7fb-ce46-43fe-9b83-070b1fd15edb")) {                    Plotly.newPlot(                        "f00cc7fb-ce46-43fe-9b83-070b1fd15edb",                        [{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Kolkata","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"Kolkata","offsetgroup":"Kolkata","orientation":"v","showlegend":true,"textposition":"auto","x":["Kolkata"],"xaxis":"x","y":[4.032934131736527],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Madhya Pradesh","marker":{"color":"#A3A500","pattern":{"shape":""}},"name":"Madhya Pradesh","offsetgroup":"Madhya Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Madhya Pradesh"],"xaxis":"x","y":[3.9771812080536915],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Jaipur","marker":{"color":"#00BF7D","pattern":{"shape":""}},"name":"Jaipur","offsetgroup":"Jaipur","orientation":"v","showlegend":true,"textposition":"auto","x":["Jaipur"],"xaxis":"x","y":[3.948717948717949],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"New Delhi","marker":{"color":"#00B0F6","pattern":{"shape":""}},"name":"New Delhi","offsetgroup":"New Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["New Delhi"],"xaxis":"x","y":[3.941405082212257],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Bangalore","marker":{"color":"#E76BF3","pattern":{"shape":""}},"name":"Bangalore","offsetgroup":"Bangalore","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangalore"],"xaxis":"x","y":[3.9177621283255086],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Hyderabad","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"Hyderabad","offsetgroup":"Hyderabad","orientation":"v","showlegend":true,"textposition":"auto","x":["Hyderabad"],"xaxis":"x","y":[3.907524329456445],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Chennai","marker":{"color":"#A3A500","pattern":{"shape":""}},"name":"Chennai","offsetgroup":"Chennai","orientation":"v","showlegend":true,"textposition":"auto","x":["Chennai"],"xaxis":"x","y":[3.901767676767677],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Kerala","marker":{"color":"#00BF7D","pattern":{"shape":""}},"name":"Kerala","offsetgroup":"Kerala","orientation":"v","showlegend":true,"textposition":"auto","x":["Kerala"],"xaxis":"x","y":[3.8839622641509433],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Pune","marker":{"color":"#00B0F6","pattern":{"shape":""}},"name":"Pune","offsetgroup":"Pune","orientation":"v","showlegend":true,"textposition":"auto","x":["Pune"],"xaxis":"x","y":[3.881487889273356],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Mumbai","marker":{"color":"#E76BF3","pattern":{"shape":""}},"name":"Mumbai","offsetgroup":"Mumbai","orientation":"v","showlegend":true,"textposition":"auto","x":["Mumbai"],"xaxis":"x","y":[3.8750375939849624],"yaxis":"y","type":"bar"}],                        {"template": ...

# %%
re = df.groupby('Employment Status', as_index=False)['Rating'].mean().sort_values(by='Rating', ascending=False)

fig = px.bar(re,
             x = 'Employment Status',
             y = 'Rating',
             color = 'Employment Status',
             template = 'ggplot2',
             title = '<b> Rating of Employment Statuse')
fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="726349f9-58f5-4b3b-94b4-a5a56c605ac5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("726349f9-58f5-4b3b-94b4-a5a56c605ac5")) {                    Plotly.newPlot(                        "726349f9-58f5-4b3b-94b4-a5a56c605ac5",                        [{"alignmentgroup":"True","hovertemplate":"Employment Status=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Intern","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"Intern","offsetgroup":"Intern","orientation":"v","showlegend":true,"textposition":"auto","x":["Intern"],"xaxis":"x","y":[3.978240076518412],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Employment Status=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Full Time","marker":{"color":"#A3A500","pattern":{"shape":""}},"name":"Full Time","offsetgroup":"Full Time","orientation":"v","showlegend":true,"textposition":"auto","x":["Full Time"],"xaxis":"x","y":[3.909312214308494],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Employment Status=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Contractor","marker":{"color":"#00BF7D","pattern":{"shape":""}},"name":"Contractor","offsetgroup":"Contractor","orientation":"v","showlegend":true,"textposition":"auto","x":["Contractor"],"xaxis":"x","y":[3.8666986564299424],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Employment Status=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"Trainee","marker":{"color":"#00B0F6","pattern":{"shape":""}},"name":"Trainee","offsetgroup":"Trainee","orientation":"v","showlegend":true,"textposition":"auto","x":["Trainee"],"xaxis":"x","y":[3.8575757575757574],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor": ...

# %%
df["Company Name"].value_counts()
# Out:
# Tata Consultancy Services         268
# Infosys                           168
# Amazon                            148
# Accenture                         146
# Cognizant Technology Solutions    139
#                                  ...
# Project42 Labs                      1
# Transfin.                           1
# ML Books International              1
# Infallible HR                       1
# Nextgen Innovation Labs             1
# Name: Company Name, Length: 10953, dtype: int64

# %%
z = df.groupby('Company Name', as_index=False)['Salary'].mean().sort_values(by='Salary', ascending=False)

fig = px.bar(z.head(10),
           x = 'Company Name',
           y = 'Salary',
           color = 'Company Name',
           text = 'Salary',
           template = 'seaborn',
           title = '<b> Salary of Company Name')
fig.update_traces(textfont_size=8)
fig.show()
# Out:
# <div>                            <div id="193223d0-6be7-449d-b126-4765d181206b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("193223d0-6be7-449d-b126-4765d181206b")) {                    Plotly.newPlot(                        "193223d0-6be7-449d-b126-4765d181206b",                        [{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"Safe Security","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"Safe Security","offsetgroup":"Safe Security","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["Safe Security"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"DevOn (Netherlands)","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""}},"name":"DevOn (Netherlands)","offsetgroup":"DevOn (Netherlands)","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["DevOn (Netherlands)"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"Silk Technologies","marker":{"color":"rgb(85,168,104)","pattern":{"shape":""}},"name":"Silk Technologies","offsetgroup":"Silk Technologies","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["Silk Technologies"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"On Campus","marker":{"color":"rgb(196,78,82)","pattern":{"shape":""}},"name":"On Campus","offsetgroup":"On Campus","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["On Campus"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"Zenius Education","marker":{"color":"rgb(129,114,179)","pattern":{"shape":""}},"name":"Zenius Education","offsetgroup":"Zenius Education","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["Zenius Education"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"AppIncubator","marker":{"color":"rgb(147,120,96)","pattern":{"shape":""}},"name":"AppIncubator","offsetgroup":"AppIncubator","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["AppIncubator"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"Offika Technologies","marker":{"color":"rgb(218,139,195)","pattern":{"shape":""}},"name":"Offika Technologies","offsetgroup":"Offika Technologies","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["Offika Technologies"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"Rahul Mishra","marker":{"color":"rgb(140,140,140)","pattern":{"shape":""}},"name":"Rahul Mishra","offsetgroup":"Rahul Mishra","orientation":"v","showlegend":true,"text":[1700000.0],"textposition":"auto","x":["Rahul Mishra"],"xaxis":"x","y":[1700000.0],"yaxis":"y","type":"bar","textfont":{"size":8}},{"alignmentgroup":"True","hovertemplate":"Company Name=%{x}<br>Salary=%{text}<extra></extra>","legendgroup":"Javis","ma ...

# %%
df.groupby('Employment Status')['Salary'].mean()
# Out:
# Employment Status
# Contractor    518950.848369
# Full Time     603959.169129
# Intern        339560.730751
# Trainee       324303.030303
# Name: Salary, dtype: float64

# %%
se = df.groupby('Employment Status',as_index=False)['Salary'].mean().sort_values(by='Salary',ascending=False)
se['Salary'] = round(se['Salary'],0)

fig=px.pie(se,
           names = 'Employment Status',
           values = 'Salary',
           color = 'Employment Status',
           hole = 0.7,
           template = 'ggplot2',
           title = '<b>Salary of Employment Status')

fig.update_layout(title_x=0.5, legend=dict(orientation='h',
                                          yanchor='bottom',
                                          y=1.02,
                                          xanchor='right',
                                          x=1))
# Out:
# <div>                            <div id="5681ad0a-077f-487a-b5f3-a0408decc6f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5681ad0a-077f-487a-b5f3-a0408decc6f7")) {                    Plotly.newPlot(                        "5681ad0a-077f-487a-b5f3-a0408decc6f7",                        [{"customdata":[["Full Time"],["Contractor"],["Intern"],["Trainee"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.7,"hovertemplate":"Employment Status=%{customdata[0]}<br>Salary=%{value}<extra></extra>","labels":["Full Time","Contractor","Intern","Trainee"],"legendgroup":"","marker":{"colors":["#F8766D","#A3A500","#00BF7D","#00B0F6"]},"name":"","showlegend":true,"values":[603959.0,518951.0,339561.0,324303.0],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ti ...
#
# var gd = document.getElementById('5681ad0a-077f-487a-b5f3-a0408decc6f7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cel

# %%
sj = df.groupby('job_category',as_index=False)['Salary'].mean().sort_values(by='Salary',ascending=False)
sj['Salary'] = round(sj['Salary'],0)

fig=px.pie(sj,
           names = 'job_category',
           values = 'Salary',
           color='job_category',
           hole = 0.7,
           labels = {'job_category':'Job Category  ','Salary':'Salary'},
           template = 'ggplot2',
           title = '<b>Salary of Job Category')

fig.update_layout(title_x=0.5, legend=dict(orientation='h',
                                          yanchor='bottom',
                                          y=1.02,
                                          xanchor='right',
                                          x=1))
# Out:
# <div>                            <div id="513a6329-b055-4516-8caf-c14970b0e991" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("513a6329-b055-4516-8caf-c14970b0e991")) {                    Plotly.newPlot(                        "513a6329-b055-4516-8caf-c14970b0e991",                        [{"customdata":[["Engineer"],["Other"],["Developer"],["Programmer"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.7,"hovertemplate":"Job Category  =%{customdata[0]}<br>Salary=%{value}<extra></extra>","labels":["Engineer","Other","Developer","Programmer"],"legendgroup":"","marker":{"colors":["#F8766D","#A3A500","#00BF7D","#00B0F6"]},"name":"","showlegend":true,"values":[648142.0,623166.0,503909.0,402260.0],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","tickl ...
#
# var gd = document.getElementById('513a6329-b055-4516-8caf-c14970b0e991');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var n

# %%
sjr = df.groupby('Job Roles',as_index=False)['Salary'].mean().sort_values(by='Salary',ascending=False)
sjr['Salary'] = round(sjr['Salary'],0)

fig=px.pie(sjr,
           names = 'Job Roles',
           values = 'Salary',
           color = 'Job Roles',
           hole = 0.7,
           template = 'ggplot2',
           title = '<b>Salary of Job Category')

fig.update_layout(title_x=0.5, legend=dict(orientation='h',
                                          yanchor='bottom',
                                          y=1.02,
                                          xanchor='right',
                                          x=1))
# Out:
# <div>                            <div id="93113e6c-4f57-46f3-b047-4f90e2d58537" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93113e6c-4f57-46f3-b047-4f90e2d58537")) {                    Plotly.newPlot(                        "93113e6c-4f57-46f3-b047-4f90e2d58537",                        [{"customdata":[["Database"],["SDE"],["Mobile"],["IOS"],["Backend"],["Frontend"],["Android"],["Java"],["Testing"],["Python"],["Web"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.7,"hovertemplate":"Job Roles=%{customdata[0]}<br>Salary=%{value}<extra></extra>","labels":["Database","SDE","Mobile","IOS","Backend","Frontend","Android","Java","Testing","Python","Web"],"legendgroup":"","marker":{"colors":["#F8766D","#A3A500","#00BF7D","#00B0F6","#E76BF3","#F8766D","#A3A500","#00BF7D","#00B0F6","#E76BF3","#F8766D"]},"name":"","showlegend":true,"values":[734573.0,680091.0,632545.0,611643.0,566296.0,521910.0,496867.0,490128.0,471059.0,457235.0,393876.0],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":" ...
#
# var gd = document.getElementById('93113e6c-4f57-46f3-b047-4f90e2d58537');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle
